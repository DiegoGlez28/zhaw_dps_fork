# %% [markdown]
# # Introduction to Process Mining with PM4PY
# Code is partially copied from this tutorial: https://medium.com/@c3_62722/process-mining-with-python-tutorial-a-healthcare-application-part-1-ae02027a050

# %%
#! pip install update pm4py==2.7.8
# Out:
# Requirement already satisfied: update in c:\users\diego\python310\lib\site-packages (0.0.1)
# Collecting pm4py==2.7.8
#   Downloading pm4py-2.7.8-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: deprecation in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (2.1.0)
# Requirement already satisfied: graphviz in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (0.20.1)
# Requirement already satisfied: intervaltree in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (3.1.0)
# Requirement already satisfied: lxml in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (4.9.3)
# Requirement already satisfied: matplotlib in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (3.9.2)
# Requirement already satisfied: networkx in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (3.1)
# Requirement already satisfied: numpy in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (1.26.4)
# Requirement already satisfied: pandas in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (2.2.2)
# Requirement already satisfied: pydotplus in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (2.0.2)
# Requirement already satisfied: pytz in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (2023.3.post1)
# Requirement already satisfied: scipy in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (1.14.0)
# Collecting stringdist (from pm4py==2.7.8)
#   Downloading StringDist-1.0.9.tar.gz (7.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (4.65.0)
# Requirement already satisfied: cvxopt in c:\users\diego\python310\lib\site-packages (from pm4py==2.7.8) (1.3.2)
# Requirement already satisfied: style==1.1.0 in c:\users\diego\python310\lib\site-packages (from update) (1.1.0)
# Requirement already satisfied: packaging in c:\users\diego\python310\lib\site-packages (from deprecation->pm4py==2.7.8) (21.3)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\diego\python310\lib\site-packages (from intervaltree->pm4py==2.7.8) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\diego\python310\lib\site-packages (from matplotlib->pm4py==2.7.8) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\diego\python310\lib\site-packages (from matplotlib->pm4py==2.7.8) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\diego\python310\lib\site-packages (from matplotlib->pm4py==2.7.8) (4.37.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\diego\python310\lib\site-packages (from matplotlib->pm4py==2.7.8) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\diego\python310\lib\site-packages (from matplotlib->pm4py==2.7.8) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\diego\python310\lib\site-packages (from matplotlib->pm4py==2.7.8) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\diego\python310\lib\site-packages (from matplotlib->pm4py==2.7.8) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\diego\python310\lib\site-packages (from pandas->pm4py==2.7.8) (2023.3)
# Requirement already satisfied: colorama in c:\users\diego\appdata\roaming\python\python310\site-packages (from tqdm->pm4py==2.7.8) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\diego\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->pm4py==2.7.8) (1.16.0)
# Downloading pm4py-2.7.8-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 1.8/1.8 MB 32.2 MB/s eta 0:00:00
# Building wheels for collected packages: stringdist
#   Building wheel for stringdist (setup.py): started
#   Building wheel for stringdist (setup.py): finished with status 'done'
#   Created wheel for stringdist: filename=StringDist-1.0.9-py3-none-any.whl size=5178 sha256=42fa165566a22fb3a8399a82d8341eacbeb69bbf750d82c253eaf84342f26690
#   Stored in directory: c:\users\diego\appdata\local\pip\cache\wheels\79\25\0a\4a0c2c7af31a8b473f6e10e30312396f31ae899722600d7b99
# Successfully built stringdist
# Installing collected packages: stringdist, pm4py
#   Attempting uninstall: pm4py
#     Found existing installation: pm4py 2.7.11.14
#     Uninstalling pm4py-2.7.11.14:
#       Successfully uninstalled pm4py-2.7.11.14
# Successfully installed pm4py-2.7.8 stringdist-1.0.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pm4py
# how pm4py version
print(pm4py.__version__)
# Out:
# 2.7.8

# %%
import pandas as pd
import numpy as np
from datetime import date
from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fn = 'ArtificialPatientTreatment.csv'
events = pd.read_csv(fn)

events.columns = ['patient', 'action', 'resource', 'datetime']
events['datetime'] = pd.to_datetime(events['datetime'])
events.head()
# Out:
#      patient           action      resource            datetime
# 0  patient 0    First consult      Dr. Anna 2017-01-02 11:40:11
# 1  patient 0       Blood test           Lab 2017-01-02 12:47:33
# 2  patient 0    Physical test   Nurse Jesse 2017-01-02 12:53:50
# 3  patient 0   Second consult      Dr. Anna 2017-01-02 16:21:06
# 4  patient 0          Surgery   Dr. Charlie 2017-01-05 13:23:09

# %%
print('{} has {} rows and {} columns.'.format(fn, events.shape[0], events.shape[1]))
# Out:
# ArtificialPatientTreatment.csv has 690 rows and 4 columns.

# %% [markdown]
# ### How many events per case?

# %%
events['patient'].value_counts().value_counts().plot(kind='bar')
plt.xlabel('Number of actions per patient')
plt.ylabel('Number of patients')
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
events['patient'].value_counts().value_counts()
# Out:
# count
# 7    90
# 6    10
# Name: count, dtype: int64

# %% [markdown]
# ### Action occurrences

# %%
events['action'].value_counts().plot(kind='bar')
plt.xlabel('action')
plt.ylabel('number of occurrences')
# Out:
# Text(0, 0.5, 'number of occurrences')

# %% [markdown]
# # Process Mining

# %%
#!pip install pm4py --user
from pm4py.objects.conversion.log import converter as log_converter
# from pm4py.objects.log.importer.xes import importer as xes_importer

# process mining 
# from pm4py.algo.discovery.alpha import algorithm as alpha_miner
# from pm4py.algo.discovery.inductive import algorithm as inductive_miner
# from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
from pm4py.algo.discovery.dfg import algorithm as dfg_discovery
from pm4py.algo.discovery.footprints import algorithm as footprints_discovery


# viz
# from pm4py.visualization.petri_net import visualizer as pn_visualizer
from pm4py.visualization.footprints import visualizer as fp_visualizer
# from pm4py.visualization.transition_system import visualizer as ts_visualizer
# from pm4py.visualization.process_tree import visualizer as pt_visualizer
# from pm4py.visualization.heuristics_net import visualizer as hn_visualizer
from pm4py.visualization.dfg import visualizer as dfg_visualization

# misc 
# from pm4py.objects.petri_net.utils import reachability_graph
# from pm4py.objects.conversion.process_tree import converter as pt_converter

import pm4py

# %%
import os
os.environ["PATH"] += os.pathsep + 'D:/Program Files/Graphviz2.38/bin/'

# %%
eventlog = events.copy()
### Specify which columns correspond to case (case:concept:name), 
###event (concept:name) and timestamp (time:timestamp) - rename columns in accordance
###with pm4py

eventlog.rename(columns={'datetime': 'time:timestamp', 'patient': 'case:concept:name', 'action': 'concept:name', 'resource': 'org:resource'}, inplace=True)

## Convert to log format
log = log_converter.apply(eventlog)

# %% [markdown]
# ### Log Exploration

# %%
# start activities
log_start = pm4py.get_start_activities(log)
log_start
# Out:
# c:\Users\diego\Python310\lib\site-packages\pm4py\utils.py:503: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")
# {' First consult': 100}

# %%
# end activities
end_activities = pm4py.get_end_activities(log)
end_activities
# Out:
# {' Final consult': 100}

# %%
# traces
variants = pm4py.get_variants_as_tuples(log)
print(len(variants))
for foot_print in variants.keys():
  print(foot_print)
# Out:
# 15
# (' First consult', ' Blood test', ' Physical test', ' Second consult', ' Surgery', ' Final consult')
# (' First consult', ' Physical test', ' Blood test', ' X-ray scan', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' Physical test', ' X-ray scan', ' Blood test', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' Blood test', ' X-ray scan', ' Physical test', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' Blood test', ' Physical test', ' X-ray scan', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' Physical test', ' X-ray scan', ' Blood test', ' Second consult', ' Surgery', ' Final consult')
# (' First consult', ' Physical test', ' Blood test', ' X-ray scan', ' Second consult', ' Surgery', ' Final consult')
# (' First consult', ' X-ray scan', ' Blood test', ' Physical test', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' Physical test', ' Blood test', ' Second consult', ' Surgery', ' Final consult')
# (' First consult', ' X-ray scan', ' Physical test', ' Blood test', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' Physical test', ' Blood test', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' X-ray scan', ' Blood test', ' Physical test', ' Second consult', ' Surgery', ' Final consult')
# (' First consult', ' Blood test', ' Physical test', ' Second consult', ' Medicine', ' Final consult')
# (' First consult', ' X-ray scan', ' Physical test', ' Blood test', ' Second consult', ' Surgery', ' Final consult')
# (' First consult', ' Blood test', ' Physical test', ' X-ray scan', ' Second consult', ' Surgery', ' Final consult')

# %%
# activities
activities = pm4py.get_event_attribute_values(log, "concept:name")
print(activities)
# Out:
# {' First consult': 100, ' Blood test': 100, ' Physical test': 100, ' Second consult': 100, ' Surgery': 20, ' Final consult': 100, ' X-ray scan': 90, ' Medicine': 80}

# %%
# resources
resources = pm4py.get_event_attribute_values(log, "org:resource")
print(resources)
# Out:
# {' Dr. Anna': 158, ' Lab': 100, ' Nurse Jesse': 57, ' Dr. Charlie': 5, ' Dr. Ben': 50, ' Team 1': 40, ' Pharmacy': 80, ' Team 2': 50, ' Nurse Corey': 43, ' Dr. Bob': 92, ' Dr. Rudy': 7, ' Dr. Alex': 5, ' Dr. Quinn': 3}

# %%
#! pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\diego\python310\lib\site-packages (0.20.1)

# %%
# dotted chart visualization
pm4py.view_dotted_chart(log)

# %%
# traces with activities carried out multiple times
rework = pm4py.get_rework_cases_per_activity(log)
rework
# Out:
# {}

# %% [markdown]
# ### Footprint Analysis

# %%
# footprint analysis
fp_log = footprints_discovery.apply(log, variant=footprints_discovery.Variants.ENTIRE_EVENT_LOG)

# %%
fp_log
# Out:
# {'dfg': Counter({(' First consult', ' Blood test'): 40,
#           (' Blood test', ' Physical test'): 35,
#           (' Physical test', ' Second consult'): 36,
#           (' Second consult', ' Surgery'): 20,
#           (' Surgery', ' Final consult'): 20,
#           (' First consult', ' Physical test'): 33,
#           (' Physical test', ' Blood test'): 33,
#           (' Blood test', ' X-ray scan'): 32,
#           (' X-ray scan', ' Second consult'): 31,
#           (' Second consult', ' Medicine'): 80,
#           (' Medicine', ' Final consult'): 80,
#           (' Physical test', ' X-ray scan'): 31,
#           (' X-ray scan', ' Blood test'): 27,
#           (' Blood test', ' Second consult'): 33,
#           (' X-ray scan', ' Physical test'): 32,
#           (' First consult', ' X-ray scan'): 27}),
#  'sequence': {(' Blood test', ' Second consult'),
#   (' First consult', ' Blood test'),
#   (' First consult', ' Physical test'),
#   (' First consult', ' X-ray scan'),
#   (' Medicine', ' Final consult'),
#   (' Physical test', ' Second consult'),
#   (' Second consult', ' Medicine'),
#   (' Second consult', ' Surgery'),
#   (' Surgery', ' Final consult'),
#   (' X-ray scan', ' Second consult')},
#  'parallel': {(' Blood test', ' Physical test'),
#   (' Blood test', ' X-ray scan'),
#   (' Physical test', ' Blood test'),
#   (' Physical test', ' X-ray scan'),
#   (' X-ray scan', ' Blood test'),
#   (' X-ray scan', ' Physical test')},
#  'start_activities': {' First consult'},
#  'end_activities': {' Final consult'},
#  'activities': {' Blood test',
#   ' Final consult',
#   ' First consult',
#   ' Medicine',
#   ' Physical test',
#   ' Second consult',
#   ' Surgery',
#   ' X-ray scan'},
#  'min_trace_length': 6}

# %% [markdown]
# ### Occurences of binary relations

# %%
fp_log['dfg']
# Out:
# Counter({(' First consult', ' Blood test'): 40,
#          (' Blood test', ' Physical test'): 35,
#          (' Physical test', ' Second consult'): 36,
#          (' Second consult', ' Surgery'): 20,
#          (' Surgery', ' Final consult'): 20,
#          (' First consult', ' Physical test'): 33,
#          (' Physical test', ' Blood test'): 33,
#          (' Blood test', ' X-ray scan'): 32,
#          (' X-ray scan', ' Second consult'): 31,
#          (' Second consult', ' Medicine'): 80,
#          (' Medicine', ' Final consult'): 80,
#          (' Physical test', ' X-ray scan'): 31,
#          (' X-ray scan', ' Blood test'): 27,
#          (' Blood test', ' Second consult'): 33,
#          (' X-ray scan', ' Physical test'): 32,
#          (' First consult', ' X-ray scan'): 27})

# %% [markdown]
# ### Causalities

# %%
fp_log['sequence']
# Out:
# {(' Blood test', ' Second consult'),
#  (' First consult', ' Blood test'),
#  (' First consult', ' Physical test'),
#  (' First consult', ' X-ray scan'),
#  (' Medicine', ' Final consult'),
#  (' Physical test', ' Second consult'),
#  (' Second consult', ' Medicine'),
#  (' Second consult', ' Surgery'),
#  (' Surgery', ' Final consult'),
#  (' X-ray scan', ' Second consult')}

# %% [markdown]
# ### Parallel

# %%
fp_log['parallel']
# Out:
# {(' Blood test', ' Physical test'),
#  (' Blood test', ' X-ray scan'),
#  (' Physical test', ' Blood test'),
#  (' Physical test', ' X-ray scan'),
#  (' X-ray scan', ' Blood test'),
#  (' X-ray scan', ' Physical test')}

# %% [markdown]
# ## Footprint table

# %%
# caution: arrows mean "causality" here NOT "follows"
gviz = fp_visualizer.apply(fp_log)
fp_visualizer.view(gviz)

# %% [markdown]
# ### Directly-follows graph

# %%
#Create graph from log (annotated with frequency)
dfg = dfg_discovery.apply(log)

# viz
gviz = dfg_visualization.apply(dfg, log=log, variant=dfg_visualization.Variants.FREQUENCY)
dfg_visualization.view(gviz)

# %%
pm4py.vis.view_dfg(dfg, log_start, end_activities)

# %%
# creatig the graph from log (annotated with time)
dfg = dfg_discovery.apply(eventlog, variant=dfg_discovery.Variants.PERFORMANCE)

# viz
gviz = dfg_visualization.apply(dfg, log=eventlog, variant=dfg_visualization.Variants.PERFORMANCE)
dfg_visualization.view(gviz)
